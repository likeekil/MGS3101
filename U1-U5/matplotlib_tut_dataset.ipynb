# %% [markdown]
# ### Matplotlib Tutorial

# %% [markdown]
# ##### 1. how to import required libraries

# %%
# import required libs
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv('top_rated_9000_movies.csv')
print(df.head())
# Out:
#     id                     title original_language release_date  vote_average  \
# 0  278  The Shawshank Redemption                en      9/23/94         8.706
# 1  238             The Godfather                en      3/14/72         8.690
# 2  240     The Godfather Part II                en     12/20/74         8.575
# 3  424          Schindler's List                en     12/15/93         8.565
# 4  389              12 Angry Men                en      4/10/57         8.546
#
#    vote_count  popularity        genre_ids                       Genres
# 0       26840     150.307         [18, 80]           ['Drama', 'Crime']
# 1       20373     122.973         [18, 80]           ['Drama', 'Crime']
# 2       12291      94.204         [18, 80]           ['Drama', 'Crime']
# 3       15695      74.615  [18, 36, 10752]  ['Drama', 'History', 'War']
# 4        8522      54.678             [18]                    ['Drama']

# %% [markdown]
# ##### 2. how to generate some random data

# %%
X_data = df['vote_average'][:100]
Y_data = df['vote_count'][:100]

# %%
print(X_data)
# Out:
# 0     8.706
# 1     8.690
# 2     8.575
# 3     8.565
# 4     8.546
#       ...
# 95    8.236
# 96    8.232
# 97    8.229
# 98    8.228
# 99    8.227
# Name: vote_average, Length: 100, dtype: float64

# %%
print(Y_data)
# Out:
# 0     26840
# 1     20373
# 2     12291
# 3     15695
# 4      8522
#       ...
# 95     2685
# 96      519
# 97     1441
# 98     2251
# 99     1522
# Name: vote_count, Length: 100, dtype: int64

# %% [markdown]
# ##### 3. how to make a scatter plot?

# %%
plt.scatter(X_data, Y_data, c = "#ff0", s = 600, marker= "*", alpha = 0.3)

plt.show()

plt.plot(X_data, Y_data, c = "g", lw = 2, linestyle = "--")

plt.show()

plt.bar(X_data, Y_data , color = "r" )

plt.show()

plt.bar(X_data, Y_data , color ="r", align ="edge", width=0.5, edgecolor="green", lw=6)

plt.show()

# %% [markdown]
# ##### 4. how to make a line plot?

# %%
# Generate some data
years = [2006 + x for x in range (16)]
weights = [80, 83, 84, 85, 86, 82, 81, 82,
           79, 83, 80,82, 82, 83, 81, 79]

# %%
# By default plt.plot will make a line plot
plt.plot(years, weights, c = "g", lw = 2, linestyle = "--")

plt.show()

# %% [markdown]
# ##### 5. how to make a bar plot?

# %%
x = ["C++", "C#", "Python", "Java", "Go"]
y = [20, 50, 140, 8 , 45]

plt.bar(x, y , color = "r")
plt.show()

# %%
# Using additional option in the plt.bar function
plt.bar(x, y , color ="r", align ="edge", width=0.5, edgecolor="green", lw=6)

plt.show()

# %% [markdown]
# ##### 6. how to make a histogram?

# %%
ages = np.random.normal(20, 1.5, 1000)

plt.hist(ages)
plt.show()

# %%
plt.hist(ages, bins = 20)
plt.show()

# %%
plt.hist(ages, bins = 20, cumulative=True)
plt.show()

# %% [markdown]
# ##### 7. how to make a pie chart?

# %%
langs = ["C++", "C#", "Python", "Java", "Go"]
votes = [50, 24, 14, 6, 17]

plt.pie(votes, labels=langs)
plt.show()

# %%
explodes = [0.3, 0, 0 ,0, 0]

plt.pie(votes, labels=langs, explode=explodes)
plt.show()

# %%
explodes = [0, 0, 0 ,0, 0]

plt.pie(votes, labels=langs, explode=explodes, autopct="%0.2f%%", pctdistance=1.3)
plt.show()

# %% [markdown]
# ##### 8. how to make a box plot?

# %%
heights = np.random.normal(172, 8, 300)

plt.boxplot(heights)
plt.show()

# %% [markdown]
# ##### 9. how to add more features in a chart?

# %%
years = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
income = [55, 56, 62, 61, 72, 72, 73, 75]

plt.plot(years, income)
plt.show()

# %%
plt.plot(years, income)
plt.title("Income of KEAN graduate (in USD)")

plt.xlabel("Year")
plt.ylabel("Yearly Income in USD")

plt.show()

# %% [markdown]
# ##### 10. how to plot multiple values variables?

# %%
stock_a = [100, 102, 105, 99, 101, 100, 103]
stock_b = [97, 98, 95, 100, 102, 103, 99]
stock_c = [110, 112, 115, 111, 108, 107, 109]

# %%
plt.plot(stock_a)
plt.plot(stock_b)
plt.plot(stock_c)

plt.show()

# %% [markdown]
# ##### 11. how to add a legend to the plot?

# %%
stock_a = [100, 102, 105, 99, 101, 100, 103]
stock_b = [97, 98, 95, 100, 102, 103, 99]
stock_c = [110, 112, 115, 111, 108, 107, 109]

plt.plot(stock_a, label = "Company A")
plt.plot(stock_b, label = "Company B")
plt.plot(stock_c, label = "Company C")

plt.legend()

plt.show()

# %% [markdown]
# ##### 12. how to add a legend to a pie chart?

# %%
votes = [10, 12, 15, 18, 20, 2]
people = ["A", "B", "C", "D", "E", "F"]

# %%
plt.pie(votes, labels=None)
plt.legend(labels = people)

plt.show()

# %% [markdown]
# ##### 12. how to use different styles in matplotlib?

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

style.use("ggplot")

# %%
votes = [10, 12, 15, 18, 20, 2]
people = ["A", "B", "C", "D", "E", "F"]

plt.pie(votes, labels=None)
plt.legend(labels=people)

plt.show()

# %%
# Use of dark background style
style.use("dark_background")

votes = [10, 12, 15, 18, 20, 2]
people = ["A", "B", "C", "D", "E", "F"]

plt.pie(votes, labels=None)
plt.legend(labels=people)

plt.show()

# %% [markdown]
# ##### 13. how to plot multiple graphs?

# %%
x1 = np.random.random(100)
y1 = np.random.random(100)  

x2 = np.arange(100)
y2 = np.random.random(100)

# %%
style.use("ggplot")
plt.figure(1)
plt.scatter(x1, y1)

plt.figure(2)
plt.plot(x2, y2)

plt.show()

# %%
x = np.arange(100)

fig, axs = plt.subplots(2, 2)

axs[0, 0].plot(x, np.sin(x))

axs[0, 1].plot(x, np.cos(x))

axs[1, 0].plot(x, np.random.random(100))

axs[1, 1].plot(x, np.tan(x))

plt.show()

# %% [markdown]
# ##### 14. how to make 3D plot in matplotlib?

# %%
ax = plt.axes(projection = "3d")

x = np.random.random(100)
y = np.random.random(100)
z = np.random.random(100)

ax.scatter(x, y, z)
ax.set_title("3D Plot")
ax.set_xlabel("test")

plt.show()

# %%
ax = plt.axes(projection = "3d")

x = np.arange(100)
y = np.sin(x)
z = np.cos(x)

ax.scatter(x, y, z)
ax.set_title("3D Plot")
ax.set_xlabel("test")

plt.show()

# %% [markdown]
# ##### 15. how to make animated plots in matplotlib?

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

import random

# %%
heads_tails = [0, 0]

# %%
for _ in range((10)):
    heads_tails[random.randint(0, 1)] +=1
    plt.bar(["Heads", "Tails"], heads_tails, color=['red', 'blue'])
    plt.pause(0.001)

plt.show()
